# %%
from pathlib import Path

import pandas as pd

# %%
pqt_pth = r'D:\projects\h3-origin-destination-matrix\testing\data\walk_parquet'

# %%
pd.read_parquet(pqt_pth)
# Out:
#          destination_id  distance_miles        time        origin_id
# 0       8928d590047ffff        0.000000    0.000000  8928d590047ffff
# 1       8928d59000bffff        0.004217    0.081452  8928d590047ffff
# 2       8928d590043ffff        0.214193    4.136673  8928d590047ffff
# 3       8928d590063ffff        0.258627    4.995115  8928d590047ffff
# 4       8928d590073ffff        0.282839    5.462741  8928d590047ffff
# ...                 ...             ...         ...              ...
# 613192  8928d59038fffff        7.977506  154.063802  8928f364bbbffff
# 613193  8928d590387ffff        7.977506  154.063802  8928f364bbbffff
# 613194  8928d59036fffff        7.982836  154.165733  8928f364bbbffff
# 613195  8928d59038bffff        7.983062  154.171224  8928f364bbbffff
# 613196  8928d591873ffff        7.991319  154.327780  8928f364bbbffff
#
# [613197 rows x 4 columns]
